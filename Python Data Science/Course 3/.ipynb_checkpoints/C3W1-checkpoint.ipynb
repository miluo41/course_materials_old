# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
fruits=pd.read_table('fruit_data_with_colors.txt')

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
lookup_fruit_name = dict(zip(fruits.fruit_label.unique(),fruits.fruit_name.unique()))

# %%
X=fruits[['mass','width','height','color_score']]
y=fruits[['fruit_label']]

# %%
# ?train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
X_train.apply(lambda x:pd.isnull(x).sum())
# Out:
# mass           0
# width          0
# height         0
# color_score    0
# dtype: int64

# %%
from matplotlib import cm

# %%
cmap=cm.get_cmap('gnuplot')
pd.plotting.scatter_matrix(X_train,c=y_train,cmap=cmap,figsize=(12,12),marker='o',s=60,hist_kwds={'bins':15});

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection = '3d')
ax.scatter(X_train['width'],X_train['height'],X_train['color_score'],
          c=y_train,marker='o',s=100)
