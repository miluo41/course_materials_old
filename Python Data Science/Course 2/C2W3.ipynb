# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.subplot(1,2,1)
x=np.arange(2,9)
plt.plot(x,'r-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x2=x**2
plt.subplot(1,2,2)
plt.plot(x2,'b-o')

# %%
plt.subplot(1,2,1)
plt.plot(x2,'b-o')

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot(x,'r-x')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot(x2,'b-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplots?

# %%
fig, ((ax1, ax2, ax3),(ax4, ax5, ax6),(ax7, ax8, ax9))=plt.subplots(3,3,sharex=True, sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax5.plot(x)

# %%
fig,((ax1, ax2), (ax3, ax4))=plt.subplots(2,2,sharex=True)
axes=[ax1,ax2,ax3,ax4]
for n in range(len(axes)):
    sample_size=10**(n+1)
    sample_norm=np.random.normal(loc=0,scale=1,size=sample_size)
    axes[n].hist(sample_norm,bins=100)
    axes[n].set_title('sample size ={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

# %%
x=np.random.random(size=10000)
y=np.random.normal(loc=0,scale=1,size=10000)

# %%
plt.figure()
gspec=gridspec.GridSpec(3,3)
top=plt.subplot(gspec[0,1:])
left=plt.subplot(gspec[1:,0])
main=plt.subplot(gspec[1:,1:])
top.hist(x,bins=1000,normed=True)
left.hist(y,bins=1000,normed=True,orientation='horizontal')
left.invert_xaxis()
main.scatter(x,y,s=0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
norm=np.random.normal(loc=0,scale=1,size=10000)
rand=np.random.random(size=10000)
gama=np.random.gamma(2,size=10000)
df=pd.DataFrame({'normal':norm,'random':rand,'gamma':gama})

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       1.990560      0.000036      0.500168
# std        1.406339      1.001703      0.288082
# min        0.019778     -4.639917      0.000173
# 25%        0.961326     -0.683732      0.249302
# 50%        1.667662     -0.002222      0.498900
# 75%        2.657397      0.673964      0.746551
# max       11.088474      3.818113      0.999994

# %%
plt.figure()
b=plt.boxplot([df['normal'],df['random'],df['gamma']],whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_=plt.hist(df.gamma,bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

# %%
plt.figure()
plt.boxplot([df.normal,df.random,df.gamma])
ax2=mpl_il.inset_axes(plt.gca(),width='60%',height='40%',loc=2)
ax2.hist(df.gamma,bins=100)
ax2.margins(x=0.4)
ax2.set_xlim(-2,15)
ax2.yaxis.tick_right()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
y=np.random.normal(loc=0,scale=1,size=10000)
x=np.random.random(size=10000)
_=plt.hist2d(x,y,bins=100)
plt.colorbar()

# %%
import matplotlib.animation as animation

# %%
n=100
x=np.random.randn(n)

# %%
def update(curr):
    if curr==n:
        a.event_scource.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis=([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_ylabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig, update, interval = 100)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
plt.figure()
data=np.random.random(size=10)
plt.plot(data)
def on_click(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixel {}, {} and data {}, {}'.format(event.x,event.y,'\n',
                                                                       event.xdata,event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event',on_click)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %%
origins=['China','Brazil','India','USA','Canada','UK','Germany','Iraq',
         'Chile','Mexico']

# %%
np.random.shuffle(origins)

# %%
plt.figure(figsize=(5,5))
height=np.random.rand(10)
weight=np.random.rand(10)
df=pd.DataFrame({'origins':origins,'height':height,'weight':weight})
plt.scatter(df.height,df.weight,picker=5)
plt.gca().set_xlabel('Weight')
plt.gca().set_ylabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
def onpick(event):
    origin=df.iloc[event.ind[0]]['origins']
    plt.gca().set_title('selected sample come from {}'.format(origin))
plt.gcf().canvas.mpl_connect('pick_event',onpick)
# Out:
# 7
