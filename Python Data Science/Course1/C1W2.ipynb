# %%
import pandas as pd

# %%
animals=['Tiger','Bear','Moose']

# %%
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals=['Tiger','Bear',None]

# %%
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers=[1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
sports={'sumo':'Japan',
       'soccer':'Brazil',
       'fencing':'Germany'}

# %%
s=pd.Series(sports)

# %%
s.index
# Out:
# Index(['fencing', 'soccer', 'sumo'], dtype='object')

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockey         NaN
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s=pd.Series(sports)

# %%
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[0]
# Out:
# 'Bhutan'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])

# %%
import numpy as np

# %%
np.sum(s)
# Out:
# 324.0

# %%
s=pd.Series(np.random.randint(0,1000,10000))

# %%
len(s)
# Out:
# 10000

# %% [markdown]
# ### Vectorized implementation

# %%
# %%timeit -n 1000
summation=0
for i in s:
    summation+=i
summation
# Out:
# 1000 loops, best of 3: 1.52 ms per loop

# %%
# %%timeit -n 1000
np.sum(s)
# Out:
# 1000 loops, best of 3: 144 µs per loop

# %%
s+=2 #every element of s

# %%
s.iteritems()

# %%
# %%timeit -n 10
s=pd.Series(np.random.randint(0,100,10))
for label,value in s.iteritems():
    s.loc[label]=value+2
# Out:
# 10 loops, best of 3: 1.38 ms per loop

# %%
# %%timeit -n 10
s=pd.Series(np.random.randint(0,100,10))
s+=2
# Out:
# 10 loops, best of 3: 279 µs per loop

# %% [markdown]
# #### Mixed types and indexing numbers are no problem

# %%
s=pd.Series([1,2,3])
s['Animal']='bear'

# %%
s
# Out:
# 0            1
# 1            2
# 2            3
# Animal    bear
# dtype: object

# %%
s[1]
# Out:
# 2

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])

# %%
all_countries=original_sports.append(cricket_loving_countries) ### pandas append doesn't change in place

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
df.iloc[2]
# Out:
# Cost                      5
# Item Purchased    Bird Seed
# Name                  Vinod
# Name: Store 2, dtype: object

# %%
df.Cost
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df.Cost
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']['Cost'] #chaining
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc['Store 1','Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.iloc[2]
# Out:
# Cost                      5
# Item Purchased    Bird Seed
# Name                  Vinod
# Name: Store 2, dtype: object

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Cost                22.5           2.5          5
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Name               Chris         Kevyn      Vinod

# %%
df.loc[:,['Cost','Item Purchased']]
# Out:
#          Cost Item Purchased
# Store 1  22.5       Dog Food
# Store 1   2.5   Kitty Litter
# Store 2   5.0      Bird Seed

# %%
df.drop('Store 1')
# Out:
#          Cost Item Purchased   Name
# Store 2   5.0      Bird Seed  Vinod

# %%
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
df.drop('Cost',axis=1)
# Out:
#         Item Purchased   Name
# Store 1       Dog Food  Chris
# Store 1   Kitty Litter  Kevyn
# Store 2      Bird Seed  Vinod

# %%
del df['Cost']

# %%
df
# Out:
#         Item Purchased   Name
# Store 1       Dog Food  Chris
# Store 1   Kitty Litter  Kevyn
# Store 2      Bird Seed  Vinod

# %%
df
# Out:
#         Item Purchased   Name
# Store 1       Dog Food  Chris
# Store 1   Kitty Litter  Kevyn
# Store 2      Bird Seed  Vinod

# %% [markdown]
# ### The issue with aliasing

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
cost=df['Cost']

# %%
cost+=2

# %%
df
# Out:
#          Cost Item Purchased   Name
# Store 1  24.5       Dog Food  Chris
# Store 1   4.5   Kitty Litter  Kevyn
# Store 2   7.0      Bird Seed  Vinod

# %%
# %ls
# Out:
#  Volume in drive C is TI10668700I
#  Volume Serial Number is 2CE7-31D0
#
#  Directory of C:\Users\miluo\Python Data Science\Course1
#
# 07/21/2017  05:14 PM    <DIR>          .
# 07/21/2017  05:14 PM    <DIR>          ..
# 07/21/2017  04:01 PM    <DIR>          .ipynb_checkpoints
# 07/19/2017  01:27 PM            10,285 C1W1.ipynb
# 07/21/2017  05:11 PM            36,742 C1W2.ipynb
# 07/21/2017  05:14 PM           116,997 olympics.csv
#                3 File(s)        164,024 bytes
#                3 Dir(s)  593,243,582,464 bytes free

# %%
df=pd.read_csv('olympics.csv',sep=',')

# %%
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df=pd.read_csv('olympics.csv',index_col=0,skiprows=1)

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]},inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]},inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]},inplace=True)

# %%
only_gold=df.where(df['Gold']>0)

# %%
only_gold.head()
# Out:
#                          № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
only_gold.dropna()
# Out:
#                                      № Summer    Gold  Silver  Bronze  \
# Algeria (ALG)                            12.0     5.0     2.0     8.0
# Argentina (ARG)                          23.0    18.0    24.0    28.0
# Armenia (ARM)                             5.0     1.0     2.0     9.0
# Australasia (ANZ) [ANZ]                   2.0     3.0     4.0     5.0
# Australia (AUS) [AUS] [Z]                25.0   139.0   152.0   177.0
# Austria (AUT)                            26.0    18.0    33.0    35.0
# Azerbaijan (AZE)                          5.0     6.0     5.0    15.0
# Bahamas (BAH)                            15.0     5.0     2.0     5.0
# Belarus (BLR)                             5.0    12.0    24.0    39.0
# Belgium (BEL)                            25.0    37.0    52.0    53.0
# Brazil (BRA)                             21.0    23.0    30.0    55.0
# Bulgaria (BUL) [H]                       19.0    51.0    85.0    78.0
# ...

# %%
df['country']=df.index

# %%
df2=df.set_index('Gold')

# %%
df2.loc[2]
# Out:
#       № Summer  Silver  Bronze  Total  № Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 2           22       7       4     13        16       0         0         0
# 2           18       6      11     19         1       0         0         0
# 2           12       9      13     24        13       0         0         0
# 2            3       4       3      9         3       0         0         0
# 2           13       7      12     21        11       0         0         0
# 2           16       5      11     18         3       0         0         0
# 2           14       3       2      7         0       0         0         0
# 2           20       2       6     10         1       0         0         0
# 2           17       2       8     12         4       0         0         0
#
#       Total.1  № Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 2           0       38       2         7         4              13
# ...

# %%
df2.reset_index()
# Out:
#      Gold  № Summer  Silver  Bronze  Total  № Winter  Gold.1  Silver.1  \
# 0       0        13       0       2      2         0       0         0
# 1       5        12       2       8     15         3       0         0
# 2      18        23      24      28     70        18       0         0
# 3       1         5       2       9     12         6       0         0
# 4       3         2       4       5     12         0       0         0
# 5     139        25     152     177    468        18       5         3
# 6      18        26      33      35     86        22      59        78
# 7       6         5       5      15     26         5       0         0
# 8       5        15       2       5     12         0       0         0
# 9       0         8       0       1      1         0       0         0
# 10      0        11       0       1      1         0       0         0
# 11     12         5      24      39     75         6       6         4
# ...

# %%
# %ls
# Out:
#  Volume in drive C is TI10668700I
#  Volume Serial Number is 2CE7-31D0
#
#  Directory of C:\Users\miluo\Python Data Science\Course1
#
# 07/21/2017  06:02 PM    <DIR>          .
# 07/21/2017  06:02 PM    <DIR>          ..
# 07/21/2017  04:01 PM    <DIR>          .ipynb_checkpoints
# 07/19/2017  01:27 PM            10,285 C1W1.ipynb
# 07/21/2017  06:01 PM           229,996 C1W2.ipynb
# 07/21/2017  06:02 PM         2,159,053 census.csv
# 07/21/2017  05:17 PM             8,419 olympics.csv
#                4 File(s)      2,407,753 bytes
#                3 Dir(s)  593,227,448,320 bytes free

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df=df[df['SUMLEV']==50]

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
df=df[columns_to_keep]

# %%
df.shape
# Out:
# (3142, 14)

# %%
df=df.set_index(['STNAME','CTYNAME'])

# %%
df.loc['Michigan','Washtenaw County']
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2010    345563
# POPESTIMATE2011    349048
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
df.loc[[('Michigan','Washtenaw County'),('Michigan','Wayne County')]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %% [markdown]
# ### Multiple indexing

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

# %%
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
df=df.set_index([df.index,'Name'])

# %%
df
# Out:
#                Cost Item Purchased
#         Name
# Store 1 Chris  22.5       Dog Food
#         Kevyn   2.5   Kitty Litter
# Store 2 Vinod   5.0      Bird Seed

# %%
df.loc['Store 1','Chris']
# Out:
# Cost                  22.5
# Item Purchased    Dog Food
# Name: (Store 1, Chris), dtype: object

# %%
df.index.names
# Out:
# FrozenList([None, 'Name'])

# %%
df.index.names=['Location','Name']

# %%
df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'},name=('Store','Kevin')))
# Out:
#                 Cost Item Purchased
# Location Name
# Store 1  Chris  22.5       Dog Food
#          Kevyn   2.5   Kitty Litter
# Store 2  Vinod   5.0      Bird Seed
# Store    Kevin   3.0     Kitty Food

# %%
df=pd.read_csv('log.csv')

# %%
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
df=df.set_index('time')

# %%
df=df.set_index([df.index,'user'])

# %%
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469977514 bob        intro.html                  1    NaN     NaN
# 1469977544 bob        intro.html                  1    NaN     NaN
# 1469977574 bob        intro.html                  1    NaN     NaN
# 1469977604 bob        intro.html                  1    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974694 cheryl     intro.html                 14    NaN     NaN
# 1469974724 cheryl     intro.html                 15    NaN     NaN
# 1469974454 sue     advanced.html                 24    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# ...

# %% [markdown]
# ## Assignment

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

# %%
name_ids=df.index.str.split('\s\(')  #Note the use of str accessor. It is an element-wise application

# %%
df.index=name_ids.str[0]
df['ID']=name_ids.str[1].str[:3]

# %%
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df=df.drop('Totals')

# %% [markdown]
# ### Problem 0

# %%
def answer_zero():
    return df.iloc[0]
answer_zero()
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %% [markdown]
# ### Problem 1
# Which country has won the most gold medals in summer games?

# %%
df.sort_values('Gold',ascending=False).index[0]
# Out:
# 'United States'

# %% [markdown]
# ### Problem 2
# Which country had the biggest difference between their summer and winter gold medal counts?

# %%
df['Difference']=abs(df['Gold']-df['Gold.1'])
df.sort_values('Difference',ascending=False).index[0]
# Out:
# 'United States'

# %% [markdown]
# ### Problem 3
# Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count?
# $$\frac{Summer~Gold - Winter~Gold}{Total~Gold}$$
#
#
# Only include countries that have won at least 1 gold in both summer and winter.

# %%
import numpy as np

with_gold=df[np.logical_and(df['Gold']>0,df['Gold.1']>0)]
with_gold['difference_frac']=abs(with_gold['Gold']-with_gold['Gold.1'])/(with_gold['Gold']+with_gold['Gold.1'])
# Out:
# C:\Users\miluo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
with_gold.sort_values('difference_frac',ascending=False).index[0]
# Out:
# 'Bulgaria'

# %% [markdown]
# ### Problem 4
# Write a function that creates a Series called "Points" which is a weighted value where each gold medal (Gold.2) counts for 3 points, silver medals (Silver.2) for 2 points, and bronze medals (Bronze.2) for 1 point. The function should return only the column (a Series object) which you created.

# %%
df.shape
# Out:
# (146, 17)

# %%
df['Gold.2']*3+df['Silver.2']*2+df['Bronze.2']
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Problem 5
# Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this for future questions too...)
# This function should return a single string value.

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df.groupby('STNAME')['COUNTY'].sum()[:5] #Not exactly what the question was asking for but an interesting code to do groupby sumerize
# Out:
# STNAME
# Alabama       4489
# Alaska        4340
# Arizona        208
# Arkansas      5625
# California    3364
# Name: COUNTY, dtype: int64

# %%
by_county=df[df['SUMLEV']==50]
by_county.groupby('STNAME').count().sort_values('SUMLEV',ascending=False).index[0]
# Out:
# 'Texas'

# %% [markdown]
# ### Problem 6
# Only looking at the three most populous counties for each state, what are the three most populous states (in order of highest population to lowest population)? Use CENSUS2010POP.

# %%
by_county=df[df['SUMLEV']==50]
ans=by_county.groupby('STNAME')['CENSUS2010POP'].apply(lambda x:x.nlargest(3).sum()).sort_values(ascending=False).index[:3]
ans=list(ans)
ans
# Out:
# ['California', 'Texas', 'Illinois']

# %% [markdown]
# ### Problem 7
#
# Which county has had the largest absolute change in population within the period 2010-2015? (Hint: population values are stored in columns POPESTIMATE2010 through POPESTIMATE2015, you need to consider all six columns.)
# e.g. If County Population in the 5 year period is 100, 120, 80, 105, 100, 130, then its largest change in the period would be |130-80| = 50.
# This function should return a single string value.

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
by_county=df[df['SUMLEV']==50]
by_county.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
county_pop=by_county.iloc[:,[6,10,11,12,13,14]]
county_pop=county_pop.set_index('CTYNAME')

# %%
county_pop.apply(lambda x:max(x)-min(x),axis=1).sort_values(ascending=False).index[0]
# Out:
# 'Harris County'

# %%
county_pop
# Out:
#                     POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# CTYNAME
# Autauga County                55253            55175            55038
# Baldwin County               186659           190396           195126
# Barbour County                27226            27159            26973
# Bibb County                   22733            22642            22512
# Blount County                 57711            57776            57734
# Bullock County                10629            10606            10628
# Butler County                 20673            20408            20261
# Calhoun County               117768           117286           116575
# Chambers County               33993            34075            34153
# Cherokee County               26080            26023            26084
# Chilton County                43739            43697            43795
# Choctaw County                13593            13543            13378
# ...

# %% [markdown]
# ### Problem 8
# In this datafile, the United States is broken up into four regions using the "REGION" column.
# Create a query that finds the counties that belong to regions 1 or 2, whose name starts with 'Washington', and whose POPESTIMATE2015 was greater than their POPESTIMATE 2014.
# This function should return a 5x2 DataFrame with the columns = ['STNAME', 'CTYNAME'] and the same index ID as the census_df (sorted ascending by index)

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
Washington=df[df['CTYNAME'].str[:10]=='Washington']
Washington_1_2=Washington[Washington['REGION'].isin([1,2])]
Washington_final=Washington_1_2[Washington_1_2['POPESTIMATE2015']>Washington_1_2['POPESTIMATE2014']]

# %%
ans=Washington_final.set_index(['STNAME','CTYNAME'])
# Out:
#                                 SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME       CTYNAME
# Iowa         Washington County      50       2         4     19     183
# Minnesota    Washington County      50       2         4     27     163
# Pennsylvania Washington County      50       1         2     42     125
# Rhode Island Washington County      50       1         1     44       9
# Wisconsin    Washington County      50       2         3     55     131
#
#                                 CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME       CTYNAME
# Iowa         Washington County          21704              21704
# Minnesota    Washington County         238136             238134
# Pennsylvania Washington County         207820             207820
# Rhode Island Washington County         126979             127094
# Wisconsin    Washington County         131887             131885
#
#                                 POPESTIMATE2010  POPESTIMATE2011  \
# STNAME       CTYNAME
# ...
