# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x=np.arange(1,6,1)
y=np.array([56,39,34,34,29])

# %%
plt.figure()
bars=plt.bar(x,y,align='center',linewidth=0,color='lightslategrey')
bars[0].set_color('#1F77B4')
languages=['Python','SQL','Java','C++','Java script']
plt.xticks(x,languages,fontsize=12)
plt.tick_params(left='off',bottom='off',labelleft='off')
ax=plt.gca()
ax.axes.get_yaxis().set_visible(False)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
for bar in bars:
    plt.gca().text(bar.get_x()+bar.get_width()/2,bar.get_height()-5,str(bar.get_height())+'%',ha='center',color='w',fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.gca().get_children()
