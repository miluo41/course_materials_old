# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tmp=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])

# %%
tmp
# Out:
# a    0.059431
# b   -2.393486
# c    1.259685
# d    0.264518
# e    1.774922
# dtype: float64

# %%
tmp[0]
# Out:
# 0.059430513564604513

# %%
tmp['a']
# Out:
# 0.059430513564604513

# %%
tmp
# Out:
# a    0.059431
# b   -2.393486
# c    1.259685
# d    0.264518
# e    1.774922
# dtype: float64

# %%
df=pd.DataFrame(tmp,columns=['Column 1'])

# %%
df
# Out:
#    Column 1
# a  0.059431
# b -2.393486
# c  1.259685
# d  0.264518
# e  1.774922

# %%
df['Column 1']
# Out:
# a    0.059431
# b   -2.393486
# c    1.259685
# d    0.264518
# e    1.774922
# Name: Column 1, dtype: float64

# %%
df['Column 2'] = df['Column 1']*4

# %%
df.sort_values('Column 2')
# Out:
#    Column 1  Column 2
# b -2.393486 -9.573944
# a  0.059431  0.237722
# d  0.264518  1.058070
# c  1.259685  5.038738
# e  1.774922  7.099688

# %%
df.apply(lambda x: x.min())
# Out:
# Column 1   -2.393486
# Column 2   -9.573944
# dtype: float64

# %%
df=pd.read_csv('GlobalTemperatures.csv')

# %%
df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
df.iloc[:,:2]
# Out:
#               dt  LandAverageTemperature
# 0     1750-01-01                   3.034
# 1     1750-02-01                   3.083
# 2     1750-03-01                   5.626
# 3     1750-04-01                   8.490
# 4     1750-05-01                  11.573
# 5     1750-06-01                  12.937
# 6     1750-07-01                  15.868
# 7     1750-08-01                  14.750
# 8     1750-09-01                  11.413
# 9     1750-10-01                   6.367
# 10    1750-11-01                     NaN
# 11    1750-12-01                   2.772
# 12    1751-01-01                   2.495
# 13    1751-02-01                   0.963
# 14    1751-03-01                   5.800
# 15    1751-04-01                   7.670
# 16    1751-05-01                     NaN
# 17    1751-06-01                  13.827
# 18    1751-07-01                     NaN
# 19    1751-08-01                  14.405
# 20    1751-09-01                  10.673
# 21    1751-10-01                     NaN
# ...

# %%
df.iloc[:5,:3]
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072

# %%
df=df.iloc[:,:2]

# %%
df
# Out:
#               dt  LandAverageTemperature
# 0     1750-01-01                   3.034
# 1     1750-02-01                   3.083
# 2     1750-03-01                   5.626
# 3     1750-04-01                   8.490
# 4     1750-05-01                  11.573
# 5     1750-06-01                  12.937
# 6     1750-07-01                  15.868
# 7     1750-08-01                  14.750
# 8     1750-09-01                  11.413
# 9     1750-10-01                   6.367
# 10    1750-11-01                     NaN
# 11    1750-12-01                   2.772
# 12    1751-01-01                   2.495
# 13    1751-02-01                   0.963
# 14    1751-03-01                   5.800
# 15    1751-04-01                   7.670
# 16    1751-05-01                     NaN
# 17    1751-06-01                  13.827
# 18    1751-07-01                     NaN
# 19    1751-08-01                  14.405
# 20    1751-09-01                  10.673
# 21    1751-10-01                     NaN
# ...

# %%
df.describe()
# Out:
#        LandAverageTemperature
# count             3180.000000
# mean                 8.374731
# std                  4.381310
# min                 -2.080000
# 25%                  4.312000
# 50%                  8.610500
# 75%                 12.548250
# max                 19.021000

# %%
plt.figure(figsize=(15,5))
plt.scatter(x=df.index,
         y=df['LandAverageTemperature'],s=20)
plt.title('Average Land Temerature')
plt.xlabel('Year')
plt.ylabel('Average Land Temperature')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3192, step=1)

# %%
type(df['dt'])
# Out:
# pandas.core.series.Series

# %%
type(df['dt'])
# Out:
# pandas.core.series.Series

# %%
times=pd.DatetimeIndex(df['dt'])

# %%
grouped=df.groupby(times.year).mean()

# %%
plt.figure(figsize=(15,5))
plt.plot(grouped)

# %%
grouped.head()
# Out:
#       LandAverageTemperature
# dt
# 1750                8.719364
# 1751                7.976143
# 1752                5.779833
# 1753                8.388083
# 1754                8.469333

# %%
df[times.year==1752]
# Out:
#            dt  LandAverageTemperature
# 24 1752-01-01                   0.348
# 25 1752-02-01                     NaN
# 26 1752-03-01                   5.806
# 27 1752-04-01                   8.265
# 28 1752-05-01                     NaN
# 29 1752-06-01                     NaN
# 30 1752-07-01                     NaN
# 31 1752-08-01                     NaN
# 32 1752-09-01                     NaN
# 33 1752-10-01                   7.839
# 34 1752-11-01                   7.335
# 35 1752-12-01                   5.086

# %%
df['dt']=pd.to_datetime(df['dt'])

# %%
times=pd.DatetimeIndex(df['dt'])

# %%
# Out:
#              dt  LandAverageTemperature        dt2
# 0    1750-01-01                   3.034 1750-01-01
# 1    1750-02-01                   3.083 1750-02-01
# 2    1750-03-01                   5.626 1750-03-01
# 3    1750-04-01                   8.490 1750-04-01
# 4    1750-05-01                  11.573 1750-05-01
# 5    1750-06-01                  12.937 1750-06-01
# 6    1750-07-01                  15.868 1750-07-01
# 7    1750-08-01                  14.750 1750-08-01
# 8    1750-09-01                  11.413 1750-09-01
# 9    1750-10-01                   6.367 1750-10-01
# 10   1750-11-01                     NaN 1750-11-01
# 11   1750-12-01                   2.772 1750-12-01
# 12   1751-01-01                   2.495 1751-01-01
# 13   1751-02-01                   0.963 1751-02-01
# 14   1751-03-01                   5.800 1751-03-01
# 15   1751-04-01                   7.670 1751-04-01
# 16   1751-05-01                     NaN 1751-05-01
# ...

# %%
df.shape
# Out:
# (3192, 3)
