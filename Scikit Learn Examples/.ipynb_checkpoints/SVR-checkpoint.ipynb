# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# %%
X=np.sort(5*np.random.rand(40,1),axis=0)
y=np.sin(X).ravel()

# %%
y[::5]+=3*(0.5-np.random.rand(8))

# %%
svr_rbf=SVR(kernel='rbf',C=1e3,gamma=0.1)
svr_lin=SVR(kernel='linear',C=1e3)
svr_poly=SVR(kernel='poly',C=1e3,degree=2)
y_rbf=svr_rbf.fit(X,y).predict(X)
y_lin=svr_lin.fit(X,y).predict(X)
y_poly=svr_poly.fit(X,y).predict(X)

# %%
lw=2
plt.scatter(X,y,color='darkorange',label='data')
plt.plot(X,y_rbf,color='navy',lw=lw,label='RBF model')
plt.plot(X,y_lin,color='c',lw=lw,label='Linear model')
plt.plot(X,y_poly,color='cornflowerblue',lw=lw,label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()

# %%
y_rbf
# Out:
# array([ 0.08698286,  0.1949824 ,  0.1996604 ,  0.51918728,  0.61813844,
#         0.62964722,  0.69442636,  0.81089906,  0.88272477,  0.89340947,
#         0.89415791,  0.88236967,  0.87355144,  0.86903829,  0.84026864,
#         0.81078894,  0.80524938,  0.70433186,  0.67912627,  0.67229874,
#         0.61518907,  0.58323485,  0.52421511,  0.51961405,  0.26414099,
#         0.13835015,  0.07198459,  0.0533217 ,  0.00270111, -0.05499511,
#        -0.1847568 , -0.87315462, -0.87733051, -0.89952871, -1.04116236,
#        -1.10028068, -1.09906981, -1.06950438, -1.05604348, -0.98478945])
